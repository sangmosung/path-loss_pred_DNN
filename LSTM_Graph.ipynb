# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

# df = pd.read_csv("/home/smsung/Downloads/MilliCar-SUMO/Test/Test_data_220110/cv_s80_i60.0_k0.8606_a0.7656_n_Rainy.txt",sep='\t', names=['seq','speed','IR','k','a','Pathloss','dist','WA','BW','DR','AE'])

# x1 = df['Pathloss']

df = pd.read_csv("/home/smsung/Downloads/MilliCar-SUMO/Test/Test_data_220120/cv_s60_i0.0_k0.0_a0.0_l_S_Urban.txt",sep='\t', names=['seq','speed','IR','Pathloss','dist','WA','WC','SC'])
y1 = df['Pathloss']
df = pd.read_csv("/home/smsung/Downloads/MilliCar-SUMO/Test/Test_data_220120/cv_s60_i2.5_k0.8606_a0.7656_l_R_Urban.txt",sep='\t', names=['seq','speed','IR','Pathloss','dist','WA','WC','SC'])
y2 = df['Pathloss']
df = pd.read_csv("/home/smsung/Downloads/MilliCar-SUMO/Test/Test_data_220120/cv_s60_i2.5_k0.8606_a0.7656_l_RS_Urban.txt",sep='\t', names=['seq','speed','IR','Pathloss','dist','WA','WC','SC'])
y3 = df['Pathloss']
x  = df['seq']
df = pd.read_csv("/home/smsung/Downloads/MilliCar-SUMO/Test/Test_data_220120/cv_s60_i2.5_k0.8606_a0.7656_l_R_Highway.txt",sep='\t', names=['seq','speed','IR','Pathloss','dist','WA','WC','SC'])
y4 = df['Pathloss']
df = pd.read_csv("/home/smsung/Downloads/MilliCar-SUMO/Test/Test_data_220120/cv_s60_i2.5_k0.8606_a0.7656_l_RS_Highway.txt",sep='\t', names=['seq','speed','IR','Pathloss','dist','WA','WC','SC'])
y5 = df['Pathloss']
df = pd.read_csv("/home/smsung/Downloads/MilliCar-SUMO/Test/Test_data_220120/cv_s60_i30.0_k0.8606_a0.7656_l_R_Highway.txt",sep='\t', names=['seq','speed','IR','Pathloss','dist','WA','WC','SC'])
y6 = df['Pathloss']
df = pd.read_csv("/home/smsung/Downloads/MilliCar-SUMO/Test/Test_data_220120/cv_s60_i30.0_k0.8606_a0.7656_l_RS_Highway.txt",sep='\t', names=['seq','speed','IR','Pathloss','dist','WA','WC','SC'])
y7 = df['Pathloss']
df = pd.read_csv("/home/smsung/Downloads/MilliCar-SUMO/Test/Test_data_220120/cv_s60_i0.0_k0.0_a0.0_n_S_Highway.txt",sep='\t', names=['seq','speed','IR','Pathloss','dist','WA','WC','SC'])
y8 = df['Pathloss']
df = pd.read_csv("/home/smsung/Downloads/MilliCar-SUMO/Test/Test_data_220120/cv_s60_i0.0_k0.0_a0.0_l_S_Urban.txt",sep='\t', names=['seq','speed','IR','Pathloss','dist','WA','WC','SC'])
y9 = df['Pathloss']
df = pd.read_csv("/home/smsung/Downloads/MilliCar-SUMO/Test/Test_data_220120/cv_s60_i30.0_k0.8606_a0.7656_n_RS_Urban.txt",sep='\t', names=['seq','speed','IR','Pathloss','dist','WA','WC','SC'])
y10 = df['Pathloss']
# # x1.plot(figsize=(20,12), grid=True)
# x2.plot(figsize=(20,12), grid=True, color = "green") #nlos
# # x1v.plot(figsize=(20,12), grid=True)
# x2v.plot(figsize=(20,12), grid=True, color = "red")  #nlosV
# x1a.plot(figsize=(20,12), grid=True, color = "red")
# x2a.plot(figsize=(20,12), grid=True, color = "blue") #all nlos

fig = plt.figure(figsize=(10,10)) ## 캔버스 생성
fig.set_facecolor('white') ## 캔버스 색상 설정
ax = fig.add_subplot() ## 그림 뼈대(프레임) 생성
ax.plot(x, y1) ## 선그래프 생성
ax.plot(x, y2) ## 선그래프 생성
ax.plot(x, y3) ## 선그래프 생성
ax.plot(x, y4) ## 선그래프 생성
ax.plot(x, y5) ## 선그래프 생성
ax.plot(x, y6) ## 선그래프 생성
ax.plot(x, y7) ## 선그래프 생성
ax.plot(x, y8) ## 선그래프 생성
ax.plot(x, y9) ## 선그래프 생성
ax.plot(x, y10) ## 선그래프 생성
# plt.xticks(rotation=45) ## x축 눈금 라벨 설정 - 40도 회전 
plt.title('Path loss with Weather attenuation',fontsize=20) ## 타이틀 설정
plt.grid(True)
# plt.xlim([40, 600])
# plt.ylim([110, 160])
plt.show()
